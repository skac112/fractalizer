// %%
interp.load.ivy(("skac", "funnodes_2.12", "0.0.1-SNAPSHOT"))
// Out:
// ...
// Downloaded https://repo1.maven.org/maven2/org/scalactic/scalactic_2.12/3.0.1/scalactic_2.12-3.0.1.pom
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.12.3/scala-library-2.12.3.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/typelevel/cats-core_2.12/1.2.0/cats-core_2.12-1.2.0.pom
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.12.3/scala-library-2.12.3.pom
// Downloaded https://repo1.maven.org/maven2/org/scalactic/scalactic_2.12/3.0.1/scalactic_2.12-3.0.1.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/typelevel/cats-core_2.12/1.2.0/cats-core_2.12-1.2.0.pom.sha1
// ...
// Downloaded https://repo1.maven.org/maven2/org/scalactic/scalactic_2.12/3.0.1/
// Downloaded https://repo1.maven.org/maven2/org/typelevel/cats-core_2.12/1.2.0/
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.12.3/
// ...
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.12.6/scala-library-2.12.6.pom
// ...
