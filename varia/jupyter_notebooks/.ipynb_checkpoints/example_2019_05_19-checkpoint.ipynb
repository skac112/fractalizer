// %%
interp.load.ivy("skac" %% "fractalizer" % "0.0.1-SNAPSHOT")
interp.load.ivy("skac" %% "miro" % "1.0.4-SNAPSHOT")
interp.load.ivy("skac" %% "vgutils" % "0.1.0-SNAPSHOT")

// %%
import skac.miro.draw.svg._
import skac.miro.graphics._
import skac.miro.attribs.colors._
import skac.miro._
import fractalizer.stylers.colorizers._
import fractalizer.nodes.extenders._
import skac.fractalizer._
import fractalizer.nodes.special._
import com.github.skac112.vgutils._
import scala.math._

// start color
val start_col = Color(random, random, random)
// palette
// val p = Palette.hueSpan(start_col, 7)
// styler
// val s = Selected(p)
val part = Partition.linear(0.1, 0.8, 5)
val rect = (Rect(100.0, 100.0), Point(0, 0))
val r = 4.0
val repl1 = Broom.regular(part, -.5, .5, r, 0.0, 0.0, 1)
val repl = repl1 + repl1 + repl1 + repl1 + DrawCut()
val out = repl(Seq(rect)).run._1
val g = Group(out)
val d = new Draw
d.saveToFile(g, "drawings/example_2019_05_14_4_broom.svg")
// Out:
// import skac.miro.draw.svg._
//
// import skac.miro.graphics._
//
// import skac.miro.attribs.colors._
//
// import skac.miro._
//
// import skac.fractalizer.stylers.colorizers._
//
// import skac.fractalizer.nodes.extenders._
//
// import skac.fractalizer._
//
// import skac.fractalizer.nodes.special._
//
// import com.github.skac112.vgutils._
//
// import scala.math._
//
// // start color
//
// start_col: Color = Color(
//   0.8287340448139957,
//   0.3977263732853362,
//   0.2743885519112744,
//   1.0
// )
// part: Partition = Partition(Vector(0.1, 0.275, 0.45000000000000007, 0.625, 0.8))
// rect: (Rect, Point) = (
//   Rect(100.0, 100.0, 0.0, GenericAttribs(None, None, None)),
//   Point(0.0, 0.0)
// )
// r: Double = 4.0
// repl1: Broom = Broom(
//   Partition(Vector(0.1, 0.275, 0.45000000000000007, 0.625, 0.8)),
//   Stream(
//     Twig(0.044444444444444446, -0.4945054945054945, 4.378092001296367),
//     Twig(0.1222222222222222, -0.39516287284144425, 4.153008661128037),
//     Twig(0.20000000000000004, -0.2031004709576138, 4.011869492413327),
//     Twig(0.2777777777777778, 0.08168171114599698, 4.0170853373253),
//     Twig(0.3555555555555555, 0.4591836734693878, 4.461451165075852)
//   ),
//   1,
//   None
// )
// repl: nodes.composition.Add = Add(
//   Add(
//     Add(
//       Add(
//         Broom(
//           Partition(Vector(0.1, 0.275, 0.45000000000000007, 0.625, 0.8)),
//           Stream(
//             Twig(0.044444444444444446, -0.4945054945054945, 4.378092001296367),
//             Twig(0.1222222222222222, -0.39516287284144425, 4.153008661128037),
//             Twig(0.20000000000000004, -0.2031004709576138, 4.011869492413327),
//             Twig(0.2777777777777778, 0.08168171114599698, 4.0170853373253),
//             Twig(0.3555555555555555, 0.4591836734693878, 4.461451165075852)
//           ),
//           1,
//           None
//         ),
//         Broom(
//           Partition(Vector(0.1, 0.275, 0.45000000000000007, 0.625, 0.8)),
//           Stream(
//             Twig(0.044444444444444446, -0.4945054945054945, 4.378092001296367),
//             Twig(0.1222222222222222, -0.39516287284144425, 4.153008661128037),
//             Twig(0.20000000000000004, -0.2031004709576138, 4.011869492413327),
//             Twig(0.2777777777777778, 0.08168171114599698, 4.0170853373253),
//             Twig(0.3555555555555555, 0.4591836734693878, 4.461451165075852)
//           ),
//           1,
//           None
//         )
//       ),
//       Broom(
//         Partition(Vector(0.1, 0.275, 0.45000000000000007, 0.625, 0.8)),
//         Stream(
//           Twig(0.044444444444444446, -0.4945054945054945, 4.378092001296367),
//           Twig(0.1222222222222222, -0.39516287284144425, 4.153008661128037),
//           Twig(0.20000000000000004, -0.2031004709576138, 4.011869492413327),
//           Twig(0.2777777777777778, 0.08168171114599698, 4.0170853373253),
//           Twig(0.3555555555555555, 0.4591836734693878, 4.461451165075852)
//         ),
//         1,
// ...
// out: Ensemble = List(
//   (Rect(100.0, 100.0, 0.0, GenericAttribs(None, None, None)), Point(0.0, 0.0)),
//   (
//     DirectedStripe(
//       4.444444444444445,
//       437.80920012963674,
//       -0.004945054945054945,
//       Angle(0.0, 0.0, 4.71238898038469),
//       GenericAttribs(None, None, None)
//     ),
//     Point(100.0, 4.444444444444445)
//   ),
//   (
//     DirectedStripe(
//       12.22222222222222,
//       415.30086611280365,
//       -0.003951628728414442,
//       Angle(0.0, 0.0, 4.71238898038469),
//       GenericAttribs(None, None, None)
//     ),
//     Point(100.0, 16.666666666666664)
//   ),
//   (
//     DirectedStripe(
//       20.000000000000004,
//       401.1869492413327,
//       -0.002031004709576138,
//       Angle(0.0, 0.0, 4.71238898038469),
//       GenericAttribs(None, None, None)
//     ),
//     Point(100.0, 36.66666666666667)
//   ),
//   (
//     DirectedStripe(
//       27.77777777777778,
//       401.70853373253,
//       8.168171114599698E-4,
//       Angle(0.0, 0.0, 4.71238898038469),
//       GenericAttribs(None, None, None)
// ...
// g: Group = Group(
//   List(
//     (Rect(100.0, 100.0, 0.0, GenericAttribs(None, None, None)), Point(0.0, 0.0)),
//     (
//       DirectedStripe(
//         4.444444444444445,
//         437.80920012963674,
//         -0.004945054945054945,
//         Angle(0.0, 0.0, 4.71238898038469),
//         GenericAttribs(None, None, None)
//       ),
//       Point(100.0, 4.444444444444445)
//     ),
//     (
//       DirectedStripe(
//         12.22222222222222,
//         415.30086611280365,
//         -0.003951628728414442,
//         Angle(0.0, 0.0, 4.71238898038469),
//         GenericAttribs(None, None, None)
//       ),
//       Point(100.0, 16.666666666666664)
//     ),
//     (
//       DirectedStripe(
//         20.000000000000004,
//         401.1869492413327,
//         -0.002031004709576138,
//         Angle(0.0, 0.0, 4.71238898038469),
//         GenericAttribs(None, None, None)
//       ),
//       Point(100.0, 36.66666666666667)
//     ),
//     (
//       DirectedStripe(
//         27.77777777777778,
//         401.70853373253,
//         8.168171114599698E-4,
// ...
// d: Draw = skac.miro.draw.svg.Draw@681c1a87
