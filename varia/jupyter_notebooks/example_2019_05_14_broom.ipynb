// %%
interp.load.ivy("skac112" %% "fractalizer" % "0.5.1-SNAPSHOT")
interp.load.ivy("skac112" %% "miro" % "1.0.6-SNAPSHOT")
interp.load.ivy("skac112" %% "vgutils" % "0.1.0-SNAPSHOT")

// %%
import com.github.skac112.miro.draw.svg._
import com.github.skac112.miro.graphics._
import com.github.skac112.miro.attribs.colors._
import com.github.skac112.miro._
import com.github.skac112.fractalizer.stylers.colorizers._
import com.github.skac112.fractalizer.nodes.extenders._
import com.github.skac112.fractalizer._
import com.github.skac112.fractalizer.nodes.special._
import com.github.skac112.vgutils._
import scala.math._

// start color
val start_col = Color(random, random, random)
// palette
val p = Palette.hueSpan(start_col, 7)
// styler
val s = Selected(p)
val part = Partition.linear(0.1, 0.8, 5)
val rect = (Rect(100.0, 100.0), Point(0, 0))
val r = 4.0
val repl1 = Broom.regular(part, -.5, .5, r, 0.0, 0.0, 1, Some(s)).changeWidth(1.3)
val repl = repl1 + repl1 + repl1 + repl1 + DrawCut()
val out = repl(Seq(rect)).run._1
val g = Group(out)
val d = new Draw
d.saveToFile(g, "drawings/example_2019_11_18_1_broom.svg")
// Out:
// import com.github.skac112.miro.draw.svg._
//
// import com.github.skac112.miro.graphics._
//
// import com.github.skac112.miro.attribs.colors._
//
// import com.github.skac112.miro._
//
// import com.github.skac112.fractalizer.stylers.colorizers._
//
// import com.github.skac112.fractalizer.nodes.extenders._
//
// import com.github.skac112.fractalizer._
//
// import com.github.skac112.fractalizer.nodes.special._
//
// import com.github.skac112.vgutils._
//
// import scala.math._
//
// // start color
//
// start_col: Color = Color(
//   0.14378512022640244,
//   0.2396356432665364,
//   0.6920186931689577,
//   1.0
// )
// p: collection.immutable.IndexedSeq[Color] = Vector(
//   Color(0.14378512022640244, 0.23963564326653622, 0.6920186931689577, 1.0),
//   Color(0.5178490882798874, 0.14378512022640244, 0.6920186931689577, 1.0),
//   Color(0.6920186931689577, 0.14378512022640244, 0.39627380696440934, 1.0),
//   Color(0.6920186931689577, 0.36121092458201454, 0.14378512022640244, 1.0),
// ...
